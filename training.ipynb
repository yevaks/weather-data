# %% [markdown]
# # Aksonova Yeva

# %% [markdown]
# lab:6,\n
# var:101,\n
# P(month number)=6,\n

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
path = "weather.csv"
df = pd.read_csv(path)

# %%
df
# Out:
#      день хмарність   опади денна температура повітря  \
# 0       1       72%       -                    13.5°C
# 1       2      100%  1 м.м.                     8.0°C
# 2       3      100%  2 м.м.                     6.0°C
# 3       4      100%       -                     5.0°C
# 4       5       87%  4 м.м.                     7.5°C
# ..    ...       ...     ...                       ...
# 360    27       64%  1 м.м.                    19.5°C
# 361    28       39%       -                    17.0°C
# 362    29       38%       -                    18.5°C
# 363    30       86%  4 м.м.                    15.5°C
# 364    31       39%       -                    17.0°C
#
#     нічна температура повітря сила вітру   період
# 0                       6.0°C      4 м/с  2023-04
# 1                       8.5°C      3 м/с  2023-04
# 2                       6.0°C      4 м/с  2023-04
# 3                       2.0°C      3 м/с  2023-04
# 4                       3.0°C      5 м/с  2023-04
# ...

# %%
df.shape
# Out:
# (365, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   день                       365 non-null    int64
#  1   хмарність                  365 non-null    object
#  2   опади                      365 non-null    object
#  3   денна температура повітря  365 non-null    object
#  4   нічна температура повітря  365 non-null    object
#  5   сила вітру                 365 non-null    object
#  6   період                     365 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 20.1+ KB

# %%
pd.set_option('display.max_rows', 365)

# %%
df
# Out:
#      день хмарність   опади денна температура повітря  \
# 0       1       72%       -                    13.5°C
# 1       2      100%  1 м.м.                     8.0°C
# 2       3      100%  2 м.м.                     6.0°C
# 3       4      100%       -                     5.0°C
# 4       5       87%  4 м.м.                     7.5°C
# 5       6       95%  1 м.м.                    10.5°C
# 6       7       60%       -                    11.5°C
# 7       8       88%  1 м.м.                    14.5°C
# 8       9       58%  2 м.м.                    14.0°C
# 9      10       87%  2 м.м.                    11.5°C
# 10     11       44%       -                    15.0°C
# 11     12      100%  7 м.м.                     9.0°C
# 12     13       99%       -                    11.5°C
# 13     14      100%  1 м.м.                     8.0°C
# 14     15      100%  1 м.м.                     5.0°C
# 15     16       75%       -                    10.0°C
# ...

# %%
pd.set_option('display.max_rows', 45)

# %%
df
# Out:
#      день хмарність   опади денна температура повітря  \
# 0       1       72%       -                    13.5°C
# 1       2      100%  1 м.м.                     8.0°C
# 2       3      100%  2 м.м.                     6.0°C
# 3       4      100%       -                     5.0°C
# 4       5       87%  4 м.м.                     7.5°C
# ..    ...       ...     ...                       ...
# 360    27       64%  1 м.м.                    19.5°C
# 361    28       39%       -                    17.0°C
# 362    29       38%       -                    18.5°C
# 363    30       86%  4 м.м.                    15.5°C
# 364    31       39%       -                    17.0°C
#
#     нічна температура повітря сила вітру   період
# 0                       6.0°C      4 м/с  2023-04
# 1                       8.5°C      3 м/с  2023-04
# 2                       6.0°C      4 м/с  2023-04
# 3                       2.0°C      3 м/с  2023-04
# 4                       3.0°C      5 м/с  2023-04
# ...

# %%
df.columns
# Out:
# Index(['день', 'хмарність', 'опади', 'денна температура повітря',
#        'нічна температура повітря', 'сила вітру', 'період'],
#       dtype='object')

# %%
df['опади'].value_counts()
# Out:
# -         282
# 1 м.м.     49
# 2 м.м.     17
# 4 м.м.      7
# 3 м.м.      6
# 5 м.м.      2
# 7 м.м.      1
# 6 м.м.      1
# Name: опади, dtype: int64

# %%
df.loc[0:100, 'опади':'сила вітру']
# Out:
#       опади денна температура повітря нічна температура повітря сила вітру
# 0         -                    13.5°C                     6.0°C      4 м/с
# 1    1 м.м.                     8.0°C                     8.5°C      3 м/с
# 2    2 м.м.                     6.0°C                     6.0°C      4 м/с
# 3         -                     5.0°C                     2.0°C      3 м/с
# 4    4 м.м.                     7.5°C                     3.0°C      5 м/с
# ..      ...                       ...                       ...        ...
# 96        -                    -5.0°C                    -8.0°C      4 м/с
# 97        -                    -3.5°C                    -6.0°C      7 м/с
# 98        -                    -2.5°C                    -4.0°C      6 м/с
# 99        -                    -3.5°C                    -5.0°C      5 м/с
# 100       -                    -2.5°C                    -6.5°C      3 м/с
#
# [101 rows x 4 columns]

# %% [markdown]
# ~~~VIDEO_4

# %%
pd.set_option('display.max_rows', 45)

# %%
filt=((df['опади']=='1 м.м.') & (df['нічна температура повітря']=='8.5°C'))
df.loc[filt, 'хмарність']
# Out:
# 1      100%
# 19      85%
# 161     75%
# Name: хмарність, dtype: object

# %%
df.loc[~filt, ['опади','нічна температура повітря', 'хмарність']]#~oposite
# Out:
#       опади нічна температура повітря хмарність
# 0         -                     6.0°C       72%
# 2    2 м.м.                     6.0°C      100%
# 3         -                     2.0°C      100%
# 4    4 м.м.                     3.0°C       87%
# 5    1 м.м.                     9.0°C       95%
# ..      ...                       ...       ...
# 360  1 м.м.                    13.0°C       64%
# 361       -                    10.0°C       39%
# 362       -                    10.5°C       38%
# 363  4 м.м.                    12.5°C       86%
# 364       -                    13.5°C       39%
#
# [362 rows x 3 columns]

# %%
gr=['6.0°C', '8.0°C', '4.5°C']
filt=df['нічна температура повітря'].isin(gr)
df.loc[filt, ['нічна температура повітря', 'хмарність']]
# Out:
#     нічна температура повітря хмарність
# 0                       6.0°C       72%
# 2                       6.0°C      100%
# 6                       4.5°C       60%
# 8                       8.0°C       58%
# 13                      8.0°C      100%
# 15                      6.0°C       75%
# 17                      8.0°C       90%
# 18                      8.0°C       65%
# 27                      4.5°C       25%
# 43                      4.5°C       38%
# 45                      6.0°C      100%
# 51                      8.0°C       86%
# 81                      4.5°C       86%
# 90                      8.0°C       19%
# 92                      4.5°C       75%
# 106                     6.0°C       96%
# 153                     8.0°C       94%
# 154                     8.0°C       50%
# 158                     6.0°C       41%
# 159                     6.0°C       11%
# 160                     6.0°C       48%
# 162                     6.0°C       25%
# ...

# %% [markdown]
# ~~~VIDEO_5

# %% [markdown]
# #updating rows and columns

# %%
df.rename(columns={'нічна температура повітря': 'н.темп.пов.', 'денна температура повітря': 'д.темп.пов.'})
# Out:
#      день хмарність   опади д.темп.пов. н.темп.пов. сила вітру   період
# 0       1       72%       -      13.5°C       6.0°C      4 м/с  2023-04
# 1       2      100%  1 м.м.       8.0°C       8.5°C      3 м/с  2023-04
# 2       3      100%  2 м.м.       6.0°C       6.0°C      4 м/с  2023-04
# 3       4      100%       -       5.0°C       2.0°C      3 м/с  2023-04
# 4       5       87%  4 м.м.       7.5°C       3.0°C      5 м/с  2023-04
# ..    ...       ...     ...         ...         ...        ...      ...
# 360    27       64%  1 м.м.      19.5°C      13.0°C      6 м/с  2022-05
# 361    28       39%       -      17.0°C      10.0°C      4 м/с  2022-05
# 362    29       38%       -      18.5°C      10.5°C      3 м/с  2022-05
# 363    30       86%  4 м.м.      15.5°C      12.5°C      4 м/с  2022-05
# 364    31       39%       -      17.0°C      13.5°C      3 м/с  2022-05
#
# [365 rows x 7 columns]

# %%
df.loc[2, 'хмарність']='70%'

# %%
df
# Out:
#      день хмарність   опади денна температура повітря  \
# 0       1       72%       -                    13.5°C
# 1       2      100%  1 м.м.                     8.0°C
# 2       3       70%  2 м.м.                     6.0°C
# 3       4      100%       -                     5.0°C
# 4       5       87%  4 м.м.                     7.5°C
# ..    ...       ...     ...                       ...
# 360    27       64%  1 м.м.                    19.5°C
# 361    28       39%       -                    17.0°C
# 362    29       38%       -                    18.5°C
# 363    30       86%  4 м.м.                    15.5°C
# 364    31       39%       -                    17.0°C
#
#     нічна температура повітря сила вітру   період
# 0                       6.0°C      4 м/с  2023-04
# 1                       8.5°C      3 м/с  2023-04
# 2                       6.0°C      4 м/с  2023-04
# 3                       2.0°C      3 м/с  2023-04
# 4                       3.0°C      5 м/с  2023-04
# ...

# %%
filt = (df['опади'] == '-')
df.loc[filt, 'опади']=''
# bellow will be function for this

# %%
df
# Out:
#      день хмарність   опади денна температура повітря  \
# 0       1       72%                            13.5°C
# 1       2      100%  1 м.м.                     8.0°C
# 2       3       70%  2 м.м.                     6.0°C
# 3       4      100%                             5.0°C
# 4       5       87%  4 м.м.                     7.5°C
# ..    ...       ...     ...                       ...
# 360    27       64%  1 м.м.                    19.5°C
# 361    28       39%                            17.0°C
# 362    29       38%                            18.5°C
# 363    30       86%  4 м.м.                    15.5°C
# 364    31       39%                            17.0°C
#
#     нічна температура повітря сила вітру   період
# 0                       6.0°C      4 м/с  2023-04
# 1                       8.5°C      3 м/с  2023-04
# 2                       6.0°C      4 м/с  2023-04
# 3                       2.0°C      3 м/с  2023-04
# 4                       3.0°C      5 м/с  2023-04
# ...

# %% [markdown]
# - apply #applying a function(застосовувати)
# - map
# - applymap #applying a function for every series
# - replace

# %%
df['сила вітру']=df['сила вітру'].apply(lambda x: x.upper())
#or instead of liambda we can create a function

# %%
df
# Out:
#      день хмарність   опади денна температура повітря  \
# 0       1       72%                            13.5°C
# 1       2      100%  1 м.м.                     8.0°C
# 2       3       70%  2 м.м.                     6.0°C
# 3       4      100%                             5.0°C
# 4       5       87%  4 м.м.                     7.5°C
# ..    ...       ...     ...                       ...
# 360    27       64%  1 м.м.                    19.5°C
# 361    28       39%                            17.0°C
# 362    29       38%                            18.5°C
# 363    30       86%  4 м.м.                    15.5°C
# 364    31       39%                            17.0°C
#
#     нічна температура повітря сила вітру   період
# 0                       6.0°C      4 М/С  2023-04
# 1                       8.5°C      3 М/С  2023-04
# 2                       6.0°C      4 М/С  2023-04
# 3                       2.0°C      3 М/С  2023-04
# 4                       3.0°C      5 М/С  2023-04
# ...

# %%
df['опади']=df['опади'].replace({'1 м.м.':'dick', '4 м.м.': 'pic'})

# %%
df
# Out:
#      день хмарність   опади денна температура повітря  \
# 0       1       72%                            13.5°C
# 1       2      100%    dick                     8.0°C
# 2       3       70%  2 м.м.                     6.0°C
# 3       4      100%                             5.0°C
# 4       5       87%     pic                     7.5°C
# ..    ...       ...     ...                       ...
# 360    27       64%    dick                    19.5°C
# 361    28       39%                            17.0°C
# 362    29       38%                            18.5°C
# 363    30       86%     pic                    15.5°C
# 364    31       39%                            17.0°C
#
#     нічна температура повітря сила вітру   період
# 0                       6.0°C      4 М/С  2023-04
# 1                       8.5°C      3 М/С  2023-04
# 2                       6.0°C      4 М/С  2023-04
# 3                       2.0°C      3 М/С  2023-04
# 4                       3.0°C      5 М/С  2023-04
# ...

# %%
df.head()
# Out:
#    день хмарність   опади денна температура повітря нічна температура повітря  \
# 0     1       72%                            13.5°C                     6.0°C
# 1     2      100%    dick                     8.0°C                     8.5°C
# 2     3       70%  2 м.м.                     6.0°C                     6.0°C
# 3     4      100%                             5.0°C                     2.0°C
# 4     5       87%     pic                     7.5°C                     3.0°C
#
#   сила вітру   період
# 0      4 М/С  2023-04
# 1      3 М/С  2023-04
# 2      4 М/С  2023-04
# 3      3 М/С  2023-04
# 4      5 М/С  2023-04

# %%
df.drop(index=3)
# Out:
#      день хмарність   опади денна температура повітря  \
# 0       1       72%                            13.5°C
# 1       2      100%    dick                     8.0°C
# 2       3       70%  2 м.м.                     6.0°C
# 4       5       87%     pic                     7.5°C
# 5       6       95%    dick                    10.5°C
# ..    ...       ...     ...                       ...
# 360    27       64%    dick                    19.5°C
# 361    28       39%                            17.0°C
# 362    29       38%                            18.5°C
# 363    30       86%     pic                    15.5°C
# 364    31       39%                            17.0°C
#
#     нічна температура повітря сила вітру   період
# 0                       6.0°C      4 М/С  2023-04
# 1                       8.5°C      3 М/С  2023-04
# 2                       6.0°C      4 М/С  2023-04
# 4                       3.0°C      5 М/С  2023-04
# 5                       9.0°C      5 М/С  2023-04
# ...

# %%
filt= df['сила вітру']== '5 М/С'
df.drop(index=df[filt].index)
# Out:
#      день хмарність   опади денна температура повітря  \
# 0       1       72%                            13.5°C
# 1       2      100%    dick                     8.0°C
# 2       3       70%  2 м.м.                     6.0°C
# 3       4      100%                             5.0°C
# 6       7       60%                            11.5°C
# ..    ...       ...     ...                       ...
# 360    27       64%    dick                    19.5°C
# 361    28       39%                            17.0°C
# 362    29       38%                            18.5°C
# 363    30       86%     pic                    15.5°C
# 364    31       39%                            17.0°C
#
#     нічна температура повітря сила вітру   період
# 0                       6.0°C      4 М/С  2023-04
# 1                       8.5°C      3 М/С  2023-04
# 2                       6.0°C      4 М/С  2023-04
# 3                       2.0°C      3 М/С  2023-04
# 6                       4.5°C      2 М/С  2023-04
# ...

# %%
df['хм+опади']= df['хмарність']+ ' ' + df['опади']

# %%
df
# Out:
#      день хмарність   опади денна температура повітря  \
# 0       1       72%                            13.5°C
# 1       2      100%    dick                     8.0°C
# 2       3       70%  2 м.м.                     6.0°C
# 3       4      100%                             5.0°C
# 4       5       87%     pic                     7.5°C
# ..    ...       ...     ...                       ...
# 360    27       64%    dick                    19.5°C
# 361    28       39%                            17.0°C
# 362    29       38%                            18.5°C
# 363    30       86%     pic                    15.5°C
# 364    31       39%                            17.0°C
#
#     нічна температура повітря сила вітру   період    хм+опади
# 0                       6.0°C      4 М/С  2023-04        72%
# 1                       8.5°C      3 М/С  2023-04   100% dick
# 2                       6.0°C      4 М/С  2023-04  70% 2 м.м.
# 3                       2.0°C      3 М/С  2023-04       100%
# ...

# %%
df.drop(columns='день', inplace= True)
df
# Out:
#     хмарність   опади денна температура повітря нічна температура повітря  \
# 0         72%                            13.5°C                     6.0°C
# 1        100%    dick                     8.0°C                     8.5°C
# 2         70%  2 м.м.                     6.0°C                     6.0°C
# 3        100%                             5.0°C                     2.0°C
# 4         87%     pic                     7.5°C                     3.0°C
# ..        ...     ...                       ...                       ...
# 360       64%    dick                    19.5°C                    13.0°C
# 361       39%                            17.0°C                    10.0°C
# 362       38%                            18.5°C                    10.5°C
# 363       86%     pic                    15.5°C                    12.5°C
# 364       39%                            17.0°C                    13.5°C
#
#     сила вітру   період    хм+опади
# 0        4 М/С  2023-04        72%
# ...

# %% [markdown]
# df[['хм', 'опади']] = df['хм+опади'].str.split(' ', expand=True)
# #code for spliting the column

# %% [markdown]
# ~~~VIDEO_7

# %%
df.sort_values(by=['хмарність', 'сила вітру'], ascending=[True, False]).head(12)
# Out:
#     хмарність   опади денна температура повітря нічна температура повітря  \
# 323        0%                            32.0°C                    18.5°C
# 274        0%                            29.5°C                    17.5°C
# 113        0%                             3.0°C                    -2.0°C
# 83         1%                             0.5°C                    -4.5°C
# 188        1%                            18.5°C                     8.5°C
# 31        10%                             5.5°C                    -1.0°C
# 186       10%                            19.5°C                     9.5°C
# 105      100%                             4.5°C                     3.0°C
# 14       100%    dick                     5.0°C                     5.0°C
# 57       100%     pic                     7.5°C                     9.0°C
# 93       100%    dick                     6.5°C                     2.0°C
# 221      100%  5 м.м.                    11.0°C                     9.5°C
#
# ...

# %%
#df.nlargest(10, 'нічна температура повітря')
#df['нічна температура повітря'].nlargest(10)   use not for str

# %% [markdown]
# ~~~VIDEO_8

# %%
df['хмарність']
# Out:
# 0       72%
# 1      100%
# 2       70%
# 3      100%
# 4       87%
#        ...
# 360     64%
# 361     39%
# 362     38%
# 363     86%
# 364     39%
# Name: хмарність, Length: 365, dtype: object

# %%
df['хмарність'].value_counts()
# Out:
# 100%    21
# 95%      8
# 86%      8
# 47%      8
# 99%      8
#         ..
# 13%      1
# 18%      1
# 55%      1
# 4%       1
# 56%      1
# Name: хмарність, Length: 96, dtype: int64

# %%
df['хмарність'].value_counts(normalize=True)
# Out:
# 100%    0.057534
# 95%     0.021918
# 86%     0.021918
# 47%     0.021918
# 99%     0.021918
#           ...
# 13%     0.002740
# 18%     0.002740
# 55%     0.002740
# 4%      0.002740
# 56%     0.002740
# Name: хмарність, Length: 96, dtype: float64

# %%
hmarnist_gr = df.groupby(['хмарність'])

# %%
hmarnist_gr.get_group('75%')
#filter=df['хмарність']=='75%'
#df.loc[filt] another way to write this code
# Out:
#     хмарність   опади денна температура повітря нічна температура повітря  \
# 15        75%                            10.0°C                     6.0°C
# 67        75%                            -3.5°C                    -6.0°C
# 92        75%                             4.0°C                     4.5°C
# 133       75%                            -3.5°C                    -4.5°C
# 161       75%    dick                    11.5°C                     8.5°C
# 244       75%  2 м.м.                    23.5°C                    17.0°C
#
#     сила вітру   період    хм+опади
# 15       4 М/С  2023-04        75%
# 67       2 М/С  2023-02        75%
# 92       5 М/С  2023-01        75%
# 133      3 М/С  2022-12        75%
# 161      3 М/С  2022-11    75% dick
# 244      4 М/С  2022-08  75% 2 м.м.

# %%
filter=df['хмарність']=='75%'
df.loc[filt]['денна температура повітря'].value_counts()
# Out:
# 9.0°C     3
# -1.0°C    2
# 2.5°C     2
# 3.5°C     2
# 9.5°C     2
# -2.5°C    2
# 7.5°C     1
# 30.5°C    1
# 34.0°C    1
# 22.5°C    1
# 23.5°C    1
# 21.0°C    1
# 26.0°C    1
# 13.0°C    1
# 24.0°C    1
# 15.0°C    1
# 16.5°C    1
# 29.5°C    1
# 16.0°C    1
# 11.0°C    1
# 14.5°C    1
# 10.5°C    1
# 0.0°C     1
# 5.5°C     1
# -3.5°C    1
# 4.0°C     1
# 0.5°C     1
# 3.0°C     1
# 12.5°C    1
# 18.0°C    1
# Name: денна температура повітря, dtype: int64

# %%
hmarnist_gr['денна температура повітря'].value_counts().head(20)
# Out:
# хмарність  денна температура повітря
# 0%         29.5°C                       1
#            3.0°C                        1
#            32.0°C                       1
# 1%         0.5°C                        1
#            18.5°C                       1
# 10%        19.5°C                       1
#            5.5°C                        1
# 100%       2.0°C                        3
#            5.0°C                        3
#            0.0°C                        2
#            1.0°C                        2
#            8.0°C                        2
#            9.0°C                        2
#            1.5°C                        1
#            11.0°C                       1
#            3.0°C                        1
#            4.5°C                        1
#            6.5°C                        1
#            7.5°C                        1
#            9.5°C                        1
# Name: денна температура повітря, dtype: int64

# %%
hmarnist_gr['денна температура повітря'].value_counts().head(20).loc['0%']
#to highlight defined group without creating a filter
# Out:
# денна температура повітря
# 29.5°C    1
# 3.0°C     1
# 32.0°C    1
# Name: денна температура повітря, dtype: int64

# %%
filter=df['хмарність']=='75%'
df.loc[filt]['денна температура повітря'].str.contains('-')
# Out:
# 4      False
# 5      False
# 19     False
# 27     False
# 34     False
# 46     False
# 71     False
# 79     False
# 91     False
# 92     False
# 94      True
# 99      True
# 123     True
# 125     True
# 126     True
# 130    False
# 146    False
# 147    False
# 148    False
# 169    False
# 184    False
# 190    False
# 199    False
# 211    False
# 235    False
# 254    False
# 255    False
# 264    False
# 283    False
# 286    False
# 292    False
# 317    False
# 327    False
# 337    False
# 348    False
# 350    False
# 351    False
# Name: денна температура повітря, dtype: bool

# %%
filter=df['хмарність']=='75%'
df.loc[filt]['денна температура повітря'].str.contains('-').sum()
# Out:
# 5
